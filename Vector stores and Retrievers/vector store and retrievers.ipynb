# %%
! pip install langchain langchain-groq langchain-community chromadb
# Out:
# Requirement already satisfied: langchain in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (0.3.26)
# Requirement already satisfied: langchain-groq in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (0.3.6)
# Requirement already satisfied: langchain-community in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (0.3.26)
# Collecting chromadb
#   Downloading chromadb-1.0.15-cp39-abi3-win_amd64.whl.metadata (7.1 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.3.69)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.4.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.10.6)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.12.2)
# Requirement already satisfied: packaging>=23.2 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (24.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet>=1 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.1)
# Requirement already satisfied: groq<1,>=0.29.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain-groq) (0.30.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (0.28.1)
# Requirement already satisfied: sniffio in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (1.3.1)
# Requirement already satisfied: httpcore==1.* in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain-groq) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain-groq) (0.14.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (3.11.18)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.2-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.0)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.22.1-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.35.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.35.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.35.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.21.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.66.4)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.69.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.3.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-33.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.1.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (3.10.16)
# Requirement already satisfied: rich>=10.11.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (13.9.3)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.20.0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.12.23)
# Requirement already satisfied: protobuf in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.28.2)
# Requirement already satisfied: sympy in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.35.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.35.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.35.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.35.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.56b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.56b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\chishty computer\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.33.2)
# Requirement already satisfied: filelock in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.12.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.4-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\chishty computer\appdata\local\programs\python\python312\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Downloading chromadb-1.0.15-cp39-abi3-win_amd64.whl (19.5 MB)
#    ---------------------------------------- 0.0/19.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/19.5 MB 2.1 MB/s eta 0:00:10
#    -- ------------------------------------- 1.3/19.5 MB 3.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 2.1/19.5 MB 3.2 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.6/19.5 MB 3.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.6/19.5 MB 3.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.6/19.5 MB 3.3 MB/s eta 0:00:06
#    -------- ------------------------------- 4.2/19.5 MB 2.6 MB/s eta 0:00:06
#    ----------- ---------------------------- 5.5/19.5 MB 3.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 5.8/19.5 MB 2.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 5.8/19.5 MB 2.9 MB/s eta 0:00:05
#    -------------- ------------------------- 7.1/19.5 MB 2.9 MB/s eta 0:00:05
#    --------------- ------------------------ 7.3/19.5 MB 2.9 MB/s eta 0:00:05
#    ---------------- ----------------------- 7.9/19.5 MB 2.7 MB/s eta 0:00:05
#    ----------------- ---------------------- 8.7/19.5 MB 2.8 MB/s eta 0:00:04
#    ------------------ --------------------- 8.9/19.5 MB 2.8 MB/s eta 0:00:04
#    ------------------- -------------------- 9.4/19.5 MB 2.7 MB/s eta 0:00:04
#    -------------------- ------------------- 10.0/19.5 MB 2.6 MB/s eta 0:00:04
#    -------------------- ------------------- 10.2/19.5 MB 2.6 MB/s eta 0:00:04
#    ---------------------- ----------------- 10.7/19.5 MB 2.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.3/19.5 MB 2.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.5/19.5 MB 2.5 MB/s eta 0:00:04
#    ------------------------ --------------- 12.1/19.5 MB 2.5 MB/s eta 0:00:03
#    ------------------------- -------------- 12.6/19.5 MB 2.5 MB/s eta 0:00:03
#    -------------------------- ------------- 12.8/19.5 MB 2.4 MB/s eta 0:00:03
#    --------------------------- ------------ 13.4/19.5 MB 2.4 MB/s eta 0:00:03
#    --------------------------- ------------ 13.6/19.5 MB 2.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.2/19.5 MB 2.4 MB/s eta 0:00:03
#    ------------------------------ ---------
rsa, requests-oauthlib, pyasn1-modules, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, humanfriendly, build, typer, opentelemetry-semantic-conventions, google-auth, coloredlogs, opentelemetry-sdk, onnxruntime, kubernetes, opentelemetry-exporter-otlp-proto-grpc, chromadb
#
#    ----------------------------------------  0/36 [pypika]
#    ----------------------------------------  0/36 [pypika]
#    - --------------------------------------  1/36 [durationpy]
#    -- -------------------------------------  2/36 [websockets]
#    -- -------------------------------------  2/36 [websockets]
#    -- -------------------------------------  2/36 [websockets]
#    -- -------------------------------------  2/36 [websockets]
#    -- -------------------------------------  2/36 [websockets]
#    -- -------------------------------------  2/36 [websockets]
#    -- -------------------------------------  2/36 [websockets]
#    -- -------------------------------------  2/36 [websockets]
#    -- -------------------------------------  2/36 [websockets]
#    -- -------------------------------------  2/36 [websockets]
#    -- -------------------------------------  2/36 [websockets]
#    --- ------------------------------------  3/36 [websocket-client]
#    --- ------------------------------------  3/36 [websocket-client]
#    --- ------------------------------------  3/36 [websocket-client]
#    --- ------------------------------------  3/36 [websocket-client]
#    --- ------------------------------------  3/36 [websocket-client]
#    ---- -----------------------------------  4/36 [shellingham]
#    ----- ----------------------------------  5/36 [pyreadline3]
#    ----- ----------------------------------  5/36 [pyreadline3]
#    ----- ----------------------------------  5/36 [pyreadline3]
#    ----- ----------------------------------  5/36 [pyreadline3]
#    ----- ----------------------------------  5/36 [pyreadline3]
#    ----- ----------------------------------  5/36 [pyreadline3]
#    ------ ---------------------------------  6/36 [pyproject_hooks]
#    ------- --------------------------------  7/36 [pybase64]
#    ------- --------------------------------  7/36 [pybase64]
#    -------- -------------------------------  8/36 [pyasn1]
#    -------- -------------------------------  8/36 [pyasn1]
#    -------- -------------------------------  8/36 [pyasn1]
#    -------- -------------------------------  8/36 [pyasn1]
#    -------- -------------------------------  8/36 [pyasn1]
#    ---------- -----------------------------  9/36 [overrides]
#    ---------- -----------------------------  9/36 [overrides]
#    ---------- -----------------------------  9/36 [overrides]
#    ----------- ---------------------------- 10/36 [opentelemetry-proto]
#    ----------- ---------------------------- 10/36 [opentelemetry-proto]
#    ----------- ---------------------------- 10/36 [opentelemetry-proto]
#    ----------- ---------------------------- 10/36 [opentelemetry-proto]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------ --------------------------- 11/36 [oauthlib]
#    ------------- -------------------------- 12/36 [mmh3]
#    -------------- ------------------------- 13/36 [importlib-resources]
#    -------------- ------------------------- 13/36 [importlib-resources]
#    -------------- ------------------------- 13/36 [importlib-resources]
#    -------------- ------------------------- 13/36 [importlib-resources]
#    -------------- ------------------------- 13/36 [importlib-resources]
#    -------------- ------------------------- 13/36 [importlib-resources]
#    -------------- ------------------------- 13/36 [importlib-resources]
#    -------------- ------------------------- 13/36 [importlib-resources]
#    -------------- ------------------------- 13/36 [importlib-resources]
#    -------------- ------------------------- 13/36 [importlib-resources]
#    --------------- ------------------------ 14/36 [httptools]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ---------------- ----------------------- 15/36 [googleapis-common-protos]
#    ------------------ --------------------- 17/36 [backoff]
#    ------------------ --------------------- 17/36 [backoff]
#    ------------------ --------------------- 17/36 [backoff]
#    -------------------- ------------------- 18/36 [watchfiles]
#    -------------------- ------------------- 18/36 [watchfiles]
#    -------------------- ------------------- 18/36 [watchfiles]
#    -------------------- ------------------- 18/36 [watchfiles]
#    -------------------- ------------------- 18/36 [watchfiles]
#    -------------------- ------------------- 18/36 [watchfiles]
#    -------------------- ------------------- 18/36 [watchfiles]
#    --------------------- ------------------ 19/36 [rsa]
#    --------------------- ------------------ 19/36 [rsa]
#    --------------------- ------------------ 19/36 [rsa]
#    --------------------- ------------------ 19/36 [rsa]
#    --------------------- ------------------ 19/36 [rsa]
#    --------------------- ------------------ 19/36 [rsa]
#    --------------------- ------------------ 19/36 [rsa]
#    --------------------- ------------------ 19/36 [rsa]
#    --------------------- ------------------ 19/36 [rsa]
#    --------------------- ------------------ 19/36 [rsa]
#    ---------------------- ----------------- 20/36 [requests-oauthlib]
#    ---------------------- ----------------- 20/36 [requests-oauthlib]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ----------------------- ---------------- 21/36 [pyasn1-modules]
#    ------------------------ --------------- 22/36 [posthog]
#    ------------------------ --------------- 22/36 [posthog]
#    ------------------------ --------------- 22/36 [posthog]
#    ------------------------ --------------- 22/36 [posthog]
#    ------------------------ --------------- 22/36 [posthog]
#    ------------------------ --------------- 22/36 [posthog]
#    ------------------------ --------------- 22/36 [posthog]
#    ------------------------ --------------- 22/36 [posthog]
#    ------------------------ --------------- 22/36 [posthog]
#    ------------------------ --------------- 22/36 [posthog]
#    ------------------------ --------------- 22/36 [posthog]
#    ------------------------ --------------- 22/36 [posthog]
#    ------------------------ --------------- 22/36 [posthog]
#    ------------------------ --------------- 22/36 [posthog]
#    ----------------- --------- 23/36 [opentelemetry-exporter-otlp-proto-common]
#    ----------------- --------- 23/36 [opentelemetry-exporter-otlp-proto-common]
#    ----------------- --------- 23/36 [opentelemetry-exporter-otlp-proto-common]
#    ----------------- --------- 23/36 [opentelemetry-exporter-otlp-proto-common]
#    -------------------------- ------------- 24/36 [opentelemetry-api]
#    -------------------------- ------------- 24/36 [opentelemetry-api]
#    -------------------------- ------------- 24/36 [opentelemetry-api]
#    -------------------------- ------------- 24/36 [opentelemetry-api]
#    -------------------------- ------------- 24/36 [opentelemetry-api]
#    -------------------------- ------------- 24/36 [opentelemetry-api]
#    -------------------------- ------------- 24/36 [opentelemetry-api]
#    --------------------------- ------------ 25/36 [humanfriendly]
#    --------------------------- ------------ 25/36 [humanfriendly]
#    --------------------------- ------------ 25/36 [humanfriendly]
#    --------------------------- ------------ 25/36 [humanfriendly]
#    --------------------------- ------------ 25/36 [humanfriendly]
#    --------------------------- ------------ 25/36 [humanfriendly]
#    ---------------------------- ----------- 26/36 [build]
#    ---------------------------- ----------- 26/36 [build]
#    ---------------------------- ----------- 26/36 [build]
#    ---------------------------- ----------- 26/36 [build]
#    ---------------------------- ----------- 26/36 [build]
#    ------------------------------ --------- 27/36 [typer]
#    ------------------------------ --------- 27/36 [typer]
#    ------------------------------ --------- 27/36 [typer]
#    ------------------------------ --------- 27/36 [typer]
#    ------------------------------ --------- 27/36 [typer]
#    ------------------------------ --------- 27/36 [typer]
#    ------------------------- ------- 28/36 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 28/36 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 28/36 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 28/36 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 28/36 [opentelemetry-semantic-conventions]
# ...
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [onnxruntime]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    ------------------------------------ --- 33/36 [kubernetes]
#    --------------------------- - 34/36 [opentelemetry-exporter-otlp-proto-grpc]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    ---------------------------------------- 36/36 [chromadb]
#
# Successfully installed backoff-2.2.1 bcrypt-4.3.0 build-1.2.2.post1 chromadb-1.0.15 coloredlogs-15.0.1 durationpy-0.10 google-auth-2.40.3 googleapis-common-protos-1.70.0 httptools-0.6.4 humanfriendly-10.0 importlib-resources-6.5.2 kubernetes-33.1.0 mmh3-5.1.0 oauthlib-3.3.1 onnxruntime-1.22.1 opentelemetry-api-1.35.0 opentelemetry-exporter-otlp-proto-common-1.35.0 opentelemetry-exporter-otlp-proto-grpc-1.35.0 opentelemetry-proto-1.35.0 opentelemetry-sdk-1.35.0 opentelemetry-semantic-conventions-0.56b0 overrides-7.7.0 posthog-5.4.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pybase64-1.4.2 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 requests-oauthlib-2.0.0 rsa-4.9.1 shellingham-1.5.4 typer-0.16.0 watchfiles-1.1.0 websocket-client-1.8.0 websockets-15.0.1

# %%
import os 
import getpass
from dotenv import load_dotenv
load_dotenv()

os.environ["LANGCHAIN_TRACING_V2"]="True"
os.environ["LANGCHAIN_PROJECT_NAME"]="Vector Stores and Retrievers"
os.environ["LANGCHAIN_API_KEY"]=getpass.getpass("Enter LangSmith API key: ")
os.environ["GROQ_API_KEY"]=getpass.getpass("Enter Groq Api key: ")

# %%
from langchain_core.documents import Document

documents=[
    Document(
        page_content="Dogs are great companions, known for their loyalty and friendliness.",
        metadata={"source":"mammal-pets-doc"},
    ),
    Document(
        page_content="Cats are independent pets that often enjoy their own space.",
        metadata={"source":"mammal-pets-doc"},
    ),
    Document(
        page_content="Goldfish are popular pets for beginners, requiring relatively simple care.",
        metadata={"source":"fish-pets-doc"},
        
    ),
    Document(
        page_content="Parrots are intelligent birds capable of mimicking human speech.",
        metadata={"source":"bird-pets-doc"},
        
    ),
    Document(
        page_content="Rabbits are social animals that need plenty of space to hop around.",
        metadata={"source":"mammal-pets-doc"},
    ),
]

# %%
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

vectorstore=Chroma.from_documents(
documents,
embedding=HuggingFaceEmbeddings(),
)
# Out:
# C:\Users\Chishty Computer\AppData\Local\Temp\ipykernel_6848\3427412083.py:6: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embedding=HuggingFaceEmbeddings(),

# %%
vectorstore.similarity_search("cat")
# Out:
# [Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.')]

# %%
await vectorstore.asimilarity_search("cat")
# Out:
# [Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.')]

# %%
vectorstore.similarity_search("What are some good pets?", k=2)
# Out:
# [Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.')]

# %%
vectorstore.similarity_search_with_score("cats")
# Out:
# [(Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#   1.0732450485229492),
#  (Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#   1.0732450485229492),
#  (Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#   1.364126443862915),
#  (Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#   1.364126443862915)]

# %%
embedding=HuggingFaceEmbeddings().embed_query("cat")
vectorstore.similarity_search_by_vector(embedding)
# Out:
# C:\Users\Chishty Computer\AppData\Local\Temp\ipykernel_6848\3286804295.py:1: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embedding=HuggingFaceEmbeddings().embed_query("cat")
# [Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.')]

# %%
from langchain_core.documents import Document
from langchain_core.runnables import RunnableLambda

retriever = RunnableLambda(vectorstore.similarity_search).bind(k=1) 

retriever.batch(["cat", "shark"])
# Out:
# [[Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.')],
#  [Document(metadata={'source': 'bird-pets-doc'}, page_content='Parrots are intelligent birds capable of mimicking human speech.')]]

# %%
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 1},
)

retriever.batch(["cat", "shark"])
# Out:
# [[Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.')],
#  [Document(metadata={'source': 'bird-pets-doc'}, page_content='Parrots are intelligent birds capable of mimicking human speech.')]]

# %%
! pip install -qU langchain-groq

# %%
import os
import getpass
os.environ["GROQ_API_KEY"]=getpass.getpass("Enter Groq Api key: ")

from langchain_groq import ChatGroq
llm= ChatGroq(model="llama3-8b-8192")

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough

message= """
Answer this question using the provided context only.

{question}

Context:
{context}
"""

prompt=ChatPromptTemplate.from_messages(
    [("human", message)])

rag_chain = {"context": retriever, "question": RunnablePassthrough()} | prompt | llm

# %%
response=rag_chain.invoke("tell me about cats?")
print(response.content)
# Out:
# According to the provided context, cats are independent pets that often enjoy their own space.
